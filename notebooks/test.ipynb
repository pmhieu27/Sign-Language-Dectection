# %%
import sys
print(sys.version)
print(sys.executable)
# Out:
# 3.10.20 (main, May 10 2026, 19:27:29) [Clang 22.1.3 ]
# /home/phieu/hieu/sign_language/.venv/bin/python

# %%
import pandas as pd
df = pd.read_csv("../datasets/metadata/dataset.csv")
df.head()
# Out:
#    id     video_name label person   group
# 0   1  Huyen_209.MOV    Mẹ  huyen  Nhóm A
# 1   2    Kiều_81.MOV    Mẹ   kieu  Nhóm A
# 2   3  Huyen_210.MOV    Mẹ  huyen  Nhóm A
# 3   4     Thu_54.MOV    Mẹ    thu  Nhóm A
# 4   5     Thu_57.MOV    Mẹ    thu  Nhóm D

# %%
df.loc[df['person'] == ] ==
